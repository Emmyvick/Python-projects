# %%
import pandas as pd

# %%
city_pop_file = "https://milliams.com/courses/data_analysis_python/city_pop.csv"
pd.read_csv(
    city_pop_file,
    skiprows=5,
    sep=";",
)
# Out:
#    year  London  Paris   Rome
# 0  2001   7.322  2.148  2.547
# 1  2006   7.652    NaN  2.627
# 2  2008  -1.000  2.211    NaN
# 3  2009  -1.000  2.234  2.734
# 4  2011   8.174    NaN    NaN
# 5  2012  -1.000  2.244  2.627
# 6  2015   8.615    NaN    NaN

# %%
import csv

# %%
print(dir(csv))
# Out:
# ['Dialect', 'DictReader', 'DictWriter', 'Error', 'OrderedDict', 'QUOTE_ALL', 'QUOTE_MINIMAL', 'QUOTE_NONE', 'QUOTE_NONNUMERIC', 'Sniffer', 'StringIO', '_Dialect', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '__version__', 'excel', 'excel_tab', 'field_size_limit', 'get_dialect', 'list_dialects', 're', 'reader', 'register_dialect', 'unix_dialect', 'unregister_dialect', 'writer']

# %%
import csv

path = "F:\data\google_stock_data.csv"
file = open(path,newline='')
reader = csv.reader(file)

header = next(reader)
data =[row for row in reader]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1a89844d818c> in <module>()
#       2
#       3 path = "F:\data\google_stock_data.csv"
# ----> 4 file = open(path,newline='')
#       5 reader = csv.reader(file)
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'F:\\data\\google_stock_data.csv'

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-23e7314b280c> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('data.csv')
#       4
#       5 print(df.to_string())
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-7dad1b9c3d18> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('data.csv')
#       4
#       5 print(df)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df =pd.read_csv(
    "https://milliams.com/courses/data_analysis_python/cetml1659on.dat",
    skiprows=6,
    delim_whitespace=True,
    na_values=['-99.9','-99.99'],
    
)

# %%
df.head()
# Out:
#       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1659  3.0  4.0  6.0  7.0  11.0  13.0  16.0  16.0  13.0  10.0  5.0  2.0  8.87
# 1660  0.0  4.0  6.0  9.0  11.0  14.0  15.0  16.0  13.0  10.0  6.0  5.0  9.10
# 1661  5.0  5.0  6.0  8.0  11.0  14.0  15.0  15.0  13.0  11.0  8.0  6.0  9.78
# 1662  5.0  6.0  6.0  8.0  11.0  15.0  15.0  15.0  13.0  11.0  6.0  3.0  9.52
# 1663  1.0  1.0  5.0  7.0  10.0  14.0  15.0  15.0  13.0  10.0  7.0  5.0  8.63

# %%
len ( df[df["JAN"] <0])
# Out:
# 20

# %%
df["JUN"].mean()
# Out:
# 14.334903047091412

# %%
df["JUN"] < 12.0
# Out:
# 1659    False
# 1660    False
# 1661    False
# 1662    False
# 1663    False
# 1664    False
# 1665    False
# 1666    False
# 1667    False
# 1668    False
# 1669    False
# 1670    False
# 1671    False
# 1672    False
# 1673    False
# 1674    False
# 1675     True
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
#         ...
# 1990    False
# 1991    False
# 1992    False
# 1993    False
# 1994    False
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# 2000    False
# 2001    False
# 2002    False
# 2003    False
# 2004    False
# 2005    False
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# 2011    False
# 2012    False
# 2013    False
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# 2018    False
# 2019    False
# ...

# %%
df[df["JUN"] >13]
# Out:
#       JAN  FEB  MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  DEC  \
# 1660  0.0  4.0  6.0   9.0  11.0  14.0  15.0  16.0  13.0  10.0   6.0  5.0
# 1661  5.0  5.0  6.0   8.0  11.0  14.0  15.0  15.0  13.0  11.0   8.0  6.0
# 1662  5.0  6.0  6.0   8.0  11.0  15.0  15.0  15.0  13.0  11.0   6.0  3.0
# 1663  1.0  1.0  5.0   7.0  10.0  14.0  15.0  15.0  13.0  10.0   7.0  5.0
# 1664  4.0  5.0  5.0   8.0  11.0  15.0  16.0  16.0  13.0   9.0   6.0  4.0
# 1665  1.0  1.0  5.0   7.0  10.0  14.0  16.0  15.0  13.0   9.0   6.0  2.0
# 1666  4.0  5.0  6.0   8.0  11.0  15.0  18.0  17.0  14.0  11.0   6.0  3.0
# 1667  0.0  4.0  2.0   7.0  10.0  15.0  17.0  16.0  13.0   9.0   6.0  3.0
# 1668  5.0  5.0  5.0   8.0  10.0  14.0  16.0  16.0  14.0  10.0   6.0  5.0
# 1669  1.0  4.0  5.0   7.0  11.0  15.0  17.0  16.0  14.0  10.0   6.0  2.0
# 1670  3.0  1.0  5.0   8.0  11.0  14.0  16.0  16.0  14.0  10.0   6.0  3.0
# 1671  4.0  3.5  5.0   7.5  11.5  13.5  16.0  15.5  13.5   8.5   6.0  4.0
# ...

# %%
df[df["JUN"] <12.0].count
# Out:
# <bound method DataFrame.count of       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1675  3.0  2.0  3.0  7.0  10.5  11.5  15.0  14.5  10.5   8.0  4.5  4.5  7.88
# 1749  5.3  3.6  5.3  6.8  12.3  11.9  17.2  15.6  13.8  10.1  6.7  4.7  9.49
# 1909  3.5  2.9  3.7  8.7  11.0  11.8  14.6  15.4  11.9  10.4  4.8  3.9  8.59
# 1916  7.5  3.8  3.3  8.2  11.6  11.8  15.3  16.4  13.0  10.6  6.8  1.9  9.20
# 1972  3.9  4.3  6.5  8.2  10.5  11.8  15.6  15.1  11.7  10.6  6.3  5.8  9.22>

# %%
df
# Out:
#       JAN  FEB  MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  DEC  \
# 1659  3.0  4.0  6.0   7.0  11.0  13.0  16.0  16.0  13.0  10.0   5.0  2.0
# 1660  0.0  4.0  6.0   9.0  11.0  14.0  15.0  16.0  13.0  10.0   6.0  5.0
# 1661  5.0  5.0  6.0   8.0  11.0  14.0  15.0  15.0  13.0  11.0   8.0  6.0
# 1662  5.0  6.0  6.0   8.0  11.0  15.0  15.0  15.0  13.0  11.0   6.0  3.0
# 1663  1.0  1.0  5.0   7.0  10.0  14.0  15.0  15.0  13.0  10.0   7.0  5.0
# 1664  4.0  5.0  5.0   8.0  11.0  15.0  16.0  16.0  13.0   9.0   6.0  4.0
# 1665  1.0  1.0  5.0   7.0  10.0  14.0  16.0  15.0  13.0   9.0   6.0  2.0
# 1666  4.0  5.0  6.0   8.0  11.0  15.0  18.0  17.0  14.0  11.0   6.0  3.0
# 1667  0.0  4.0  2.0   7.0  10.0  15.0  17.0  16.0  13.0   9.0   6.0  3.0
# 1668  5.0  5.0  5.0   8.0  10.0  14.0  16.0  16.0  14.0  10.0   6.0  5.0
# 1669  1.0  4.0  5.0   7.0  11.0  15.0  17.0  16.0  14.0  10.0   6.0  2.0
# 1670  3.0  1.0  5.0   8.0  11.0  14.0  16.0  16.0  14.0  10.0   6.0  3.0
# ...

# %%
import pandas as pd
from pandas import Series

# %%
import matplotlib.pyplot as plt

# %%
df =pd.read_csv(
    "https://milliams.com/courses/data_analysis_python/cetml1659on.dat",
    skiprows=6,
    delim_whitespace=True,
    na_values=['-99.9','-99.99'],
    
)
df.head()
# Out:
#       JAN  FEB  MAR  APR   MAY   JUN   JUL   AUG   SEP   OCT  NOV  DEC  YEAR
# 1659  3.0  4.0  6.0  7.0  11.0  13.0  16.0  16.0  13.0  10.0  5.0  2.0  8.87
# 1660  0.0  4.0  6.0  9.0  11.0  14.0  15.0  16.0  13.0  10.0  6.0  5.0  9.10
# 1661  5.0  5.0  6.0  8.0  11.0  14.0  15.0  15.0  13.0  11.0  8.0  6.0  9.78
# 1662  5.0  6.0  6.0  8.0  11.0  15.0  15.0  15.0  13.0  11.0  6.0  3.0  9.52
# 1663  1.0  1.0  5.0  7.0  10.0  14.0  15.0  15.0  13.0  10.0  7.0  5.0  8.63

# %%
df.plot()

# %%
df["YEAR"].plot()

# %%
year_plot=  df["YEAR"].plot()
year_plot.set_ylabel("Temperature")
# Out:
# Text(0,0.5,'Temperature')

# %%
year_plot=  df["YEAR"].plot()
year_plot.set_ylabel("Temperature")
year_plot.set_xlabel("YEAR")
# Out:
# Text(0.5,0,'YEAR')

# %% [raw]
# S

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 2.2.3

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 10])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()
